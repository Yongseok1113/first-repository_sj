# %% [markdown]
# 0. 실습환경구축

# %%
# !pip install nltk
# !pip install beautifulsoup4
# !pip install --upgrade summa
# Out:
# Collecting nltk
#   Downloading nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: click in /opt/conda/lib/python3.12/site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.12/site-packages (from nltk) (1.5.1)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2026.5.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.12/site-packages (from nltk) (4.67.1)
# Downloading nltk-3.9.4-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 11.7 MB/s eta 0:00:00a 0:00:01
# Downloading regex-2026.5.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (801 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 801.2/801.2 kB 36.1 MB/s eta 0:00:00
# Installing collected packages: regex, nltk
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [nltk]1/2 [nltk]
# Successfully installed nltk-3.9.4 regex-2026.5.9
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.12/site-packages (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.12/site-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/conda/lib/python3.12/site-packages (from beautifulsoup4) (4.14.0)
# Requirement already satisfied: summa in /opt/conda/lib/python3.12/site-packages (1.2.0)
# Requirement already satisfied: scipy>=0.19 in /opt/conda/lib/python3.12/site-packages (from summa) (1.15.2)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in /opt/conda/lib/python3.12/site-packages (from scipy>=0.19->summa) (2.2.6)

# %%
import nltk
nltk.download('stopwords')

import numpy as np
import pandas as pd
import os
import re
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from bs4 import BeautifulSoup

import torch
from collections import Counter

import urllib.request
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module='bs4')

print('=3')
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# =3

# %% [markdown]
# Step 1. 데이터 업로드

# %%
import urllib.request
urllib.request.urlretrieve("https://raw.githubusercontent.com/sunnysai12345/News_Summary/master/news_summary_more.csv", filename="news_summary_more.csv")
data = pd.read_csv('news_summary_more.csv', encoding='iso-8859-1')
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 98401

# %%
data.head()
# Out:
#                                            headlines  \
# 0  upGrad learner switches to career in ML & Al w...
# 1  Delhi techie wins free food from Swiggy for on...
# 2  New Zealand end Rohit Sharma-led India's 12-ma...
# 3  Aegon life iTerm insurance plan helps customer...
# 4  Have known Hirani for yrs, what if MeToo claim...
#
#                                                 text
# 0  Saurav Kant, an alumnus of upGrad and IIIT-B's...
# 1  Kunal Shah's credit card bill payment platform...
# 2  New Zealand defeated India by 8 wickets in the...
# 3  With Aegon Life iTerm Insurance plan, customer...
# 4  Speaking about the sexual harassment allegatio...

# %% [markdown]
# Step 2.1. 데이터 전처리(추상적요약)

# %%
print('Text 열에서 중복을 배제한 유일한 샘플의 수 :', data['text'].nunique())
print('Summary 열에서 중복을 배제한 유일한 샘플의 수 :', data['headlines'].nunique())
# Out:
# Text 열에서 중복을 배제한 유일한 샘플의 수 : 98360
# Summary 열에서 중복을 배제한 유일한 샘플의 수 : 98280

# %%
# inplace=True 를 설정하면 DataFrame 타입 값을 return 하지 않고 data 내부를 직접적으로 바꿉니다

data.drop_duplicates(subset = ['text'], inplace=True)
print('전체 샘플수 :', (len(data)))
print(data.isnull().sum())

data.dropna(axis=0, inplace=True)
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 98360
# headlines    0
# text         0
# dtype: int64
# 전체 샘플수 : 98360

# %%
# 텍스트 정규화(text normalization)

contractions = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",
                           "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",
                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",
                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",
                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",
                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",
                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",
                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",
                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",
                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",
                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",
                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",
                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",
                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",
                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",
                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",
                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",
                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",
                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",
                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",
                           "you're": "you are", "you've": "you have"}

print("정규화 사전의 수: ", len(contractions))
# Out:
# 정규화 사전의 수:  120

# %%
print('불용어 개수 :', len(stopwords.words('english') ))
print(stopwords.words('english'))
# Out:
# 불용어 개수 : 198
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]

# %%
# 데이터 전처리 함수

def preprocess_sentence(sentence, remove_stopwords=True):
    sentence = sentence.lower() # 텍스트 소문자화
    sentence = BeautifulSoup(sentence, "lxml").text # <br />, <a href = ...> 등의 html 태그 제거
    sentence = re.sub(r'\([^)]*\)', '', sentence) # 괄호로 닫힌 문자열 (...) 제거 Ex) my husband (and myself!) for => my husband for
    sentence = re.sub('"','', sentence) # 쌍따옴표 " 제거
    sentence = ' '.join([contractions[t] if t in contractions else t for t in sentence.split(" ")]) # 약어 정규화
    sentence = re.sub(r"'s\b","", sentence) # 소유격 제거. Ex) roland's -> roland
    sentence = re.sub("[^a-zA-Z]", " ", sentence) # 영어 외 문자(숫자, 특수문자 등) 공백으로 변환
    sentence = re.sub('[m]{2,}', 'mm', sentence) # m이 3개 이상이면 2개로 변경. Ex) ummmmmmm yeah -> umm yeah

    # 불용어 제거 (Text)
    if remove_stopwords:
        tokens = ' '.join(word for word in sentence.split() if not word in stopwords.words('english') if len(word) > 1)
    # 불용어 미제거 (Summary)
    else:
        tokens = ' '.join(word for word in sentence.split() if len(word) > 1)
    return tokens
print('=3')
# Out:
# =3

# %%
# !pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-6.1.1-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (3.5 kB)
# Downloading lxml-6.1.1-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 24.2 MB/s eta 0:00:00 0:00:01
# Installing collected packages: lxml
# Successfully installed lxml-6.1.1

# %%
import html
import re
from tqdm.contrib.concurrent import process_map

HTML_CLEANER = re.compile("<[^>]*>")  # BeautifulSoup 대신 사용할 태그 제거 정규식
PAREN_CLEANER = re.compile(r"\([^)]*\)")
QUOTE_CLEANER = re.compile('"')
POSSESSIVE_CLEANER = re.compile(r"'s\b")
NON_ALPHA_CLEANER = re.compile("[^a-zA-Z]")
M_CLEANER = re.compile("[m]{2,}")

stop_words = set(stopwords.words("english"))

def preprocess_sentence(sentence, remove_stopwords=True):
    sentence = sentence.lower()  # 텍스트 소문자화

    # BeautifulSoup 대신 정규식 + html.unescape 사용
    sentence = HTML_CLEANER.sub("", sentence)
    sentence = html.unescape(sentence)  # &amp; 나 &lt; 같은 html 엔티티 변환

    sentence = PAREN_CLEANER.sub("", sentence)  # 괄호 제거
    sentence = QUOTE_CLEANER.sub("", sentence)  # 쌍따옴표 제거

    # 약어 정규화 (split(" ") 대신 split()을 쓰면 연속된 공백도 깔끔하게 처리됩니다)
    sentence = " ".join(
        [contractions[t] if t in contractions else t for t in sentence.split()]
    )

    sentence = POSSESSIVE_CLEANER.sub("", sentence)  # 소유격 제거
    sentence = NON_ALPHA_CLEANER.sub(" ", sentence)  # 영어 외 문자 공백 변환
    sentence = M_CLEANER.sub("mm", sentence)  # m 연속 제거

    words = sentence.split()

    # 불용어 제거 (Set을 사용한 초고속 필터링)
    if remove_stopwords:
        tokens = " ".join(
            word for word in words if word not in stop_words and len(word) > 1
        )
    else:
        tokens = " ".join(word for word in words if len(word) > 1)

    return tokens

# %%
from tqdm import tqdm

clean_text = [preprocess_sentence(sentence) for sentence in tqdm(data['text'])]
print("Text 전처리 후 결과: ", clean_text[:5])

clean_summary = [preprocess_sentence(sentence) for sentence in tqdm(data['headlines'])]
print("Summary 전처리 후 결과: ", clean_summary[:5])
# Out:
# 100%|██████████| 98360/98360 [00:08<00:00, 12149.90it/s]
# Text 전처리 후 결과:  ['saurav kant alumnus upgrad iiit pg program machine learning artificial intelligence sr systems engineer infosys almost years work experience program upgrad degree career support helped transition data scientist tech mahindra salary hike upgrad online power learning powered lakh careers', 'kunal shah credit card bill payment platform cred gave users chance win free food swiggy one year pranav kaushik delhi techie bagged reward spending cred coins users get one cred coin per rupee bill paid used avail rewards brands like ixigo bookmyshow ubereats cult fit', 'new zealand defeated india wickets fourth odi hamilton thursday win first match five match odi series india lost international match rohit sharma captaincy consecutive victories dating back march match witnessed india getting seventh lowest total odi cricket history', 'aegon life iterm insurance plan customers enjoy tax benefits premiums paid save taxes plan provides life cover age years also customers options insure critical illnesses disability accidental death benefit rider life cover age years', 'speaking sexual harassment allegations rajkumar hirani sonam kapoor said known hirani many years true metoo movement get derailed metoo movement always believe woman case need reserve judgment added hirani accused assistant worked sanju']
# 100%|██████████| 98360/98360 [00:01<00:00, 60258.76it/s]
# Summary 전처리 후 결과:  ['upgrad learner switches career ml al salary hike', 'delhi techie wins free food swiggy one year cred', 'new zealand end rohit sharma led india match winning streak', 'aegon life iterm insurance plan helps customers save tax', 'known hirani yrs metoo claims true sonam']

# %%
data['text'] = clean_text
data['headlines'] = clean_summary

# 빈 값을 Null 값으로 변환
data.replace('', np.nan, inplace=True)
print('=3')
# Out:
# =3

# %%
data.isnull().sum()
# Out:
# headlines    0
# text         0
# dtype: int64

# %%
data.dropna(axis=0, inplace=True)
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 98360

# %%
Step 2.2 데이터 분할

# %%
# 길이 분포 출력
import matplotlib.pyplot as plt

text_len = [len(s.split()) for s in data['text']]
summary_len = [len(s.split()) for s in data['headlines']]

print('텍스트의 최소 길이 : {}'.format(np.min(text_len)))
print('텍스트의 최대 길이 : {}'.format(np.max(text_len)))
print('텍스트의 평균 길이 : {}'.format(np.mean(text_len)))
print('요약의 최소 길이 : {}'.format(np.min(summary_len)))
print('요약의 최대 길이 : {}'.format(np.max(summary_len)))
print('요약의 평균 길이 : {}'.format(np.mean(summary_len)))

plt.subplot(1,2,1)
plt.boxplot(text_len)
plt.title('Text')
plt.subplot(1,2,2)
plt.boxplot(summary_len)
plt.title('Summary')
plt.tight_layout()
plt.show()

plt.title('Text')
plt.hist(text_len, bins = 40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()

plt.title('Summary')
plt.hist(summary_len, bins = 40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 텍스트의 최소 길이 : 1
# 텍스트의 최대 길이 : 60
# 텍스트의 평균 길이 : 35.09968483123221
# 요약의 최소 길이 : 1
# 요약의 최대 길이 : 13
# 요약의 평균 길이 : 7.136183407889386

# %%
text_max_len = 50
summary_max_len = 8
print('=3')
# Out:
# =3

# %%
def below_threshold_len(max_len, nested_list):
  cnt = 0
  for s in nested_list:
    if(len(s.split()) <= max_len):
        cnt = cnt + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))))
print('=3')
# Out:
# =3

# %%
below_threshold_len(text_max_len, data['text'])
below_threshold_len(summary_max_len, data['headlines'])
# Out:
# 전체 샘플 중 길이가 50 이하인 샘플의 비율: 0.9998576657177715
# 전체 샘플 중 길이가 8 이하인 샘플의 비율: 0.8925782838552258

# %%
data = data[data['text'].apply(lambda x: len(x.split()) <= text_max_len)]
data = data[data['headlines'].apply(lambda x: len(x.split()) <= summary_max_len)]

print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 87787

# %%
# 요약 데이터에 시작/종료 토큰을 추가

data['decoder_input'] = data['headlines'].apply(lambda x : 'sostoken '+ x)
data['decoder_target'] = data['headlines'].apply(lambda x : x + ' eostoken')
data.head()
# Out:
#                                            headlines  \
# 0   upgrad learner switches career ml al salary hike
# 4           known hirani yrs metoo claims true sonam
# 6             india get lowest odi total new zealand
# 7   govt directs alok verma join work day retirement
# 9  cong wins ramgarh bypoll rajasthan takes total...
#
#                                                 text  \
# 0  saurav kant alumnus upgrad iiit pg program mac...
# 4  speaking sexual harassment allegations rajkuma...
# 6  india recorded lowest odi total new zealand ge...
# 7  weeks ex cbi director alok verma told departme...
# 9  congress candidate shafia zubair ramgarh assem...
#
#                                        decoder_input  \
# 0  sostoken upgrad learner switches career ml al ...
# 4  sostoken known hirani yrs metoo claims true sonam
# 6    sostoken india get lowest odi total new zealand
# 7  sostoken govt directs alok verma join work day...
# 9  sostoken cong wins ramgarh bypoll rajasthan ta...
#
#                                       decoder_target
# 0  upgrad learner switches career ml al salary hi...
# 4  known hirani yrs metoo claims true sonam eostoken
# 6    india get lowest odi total new zealand eostoken
# 7  govt directs alok verma join work day retireme...
# 9  cong wins ramgarh bypoll rajasthan takes total...

# %%
encoder_input = np.array(data['text']) # 인코더의 입력
decoder_input = np.array(data['decoder_input']) # 디코더의 입력
decoder_target = np.array(data['decoder_target']) # 디코더의 레이블
print('=3')
# Out:
# =3

# %%
indices = np.arange(encoder_input.shape[0])
np.random.shuffle(indices)
print(indices)
# Out:
# [ 8483 54133 67516 ...  3215 33959 56501]

# %%
encoder_input = encoder_input[indices]
decoder_input = decoder_input[indices]
decoder_target = decoder_target[indices]
print('=3')
# Out:
# =3

# %%
n_of_val = int(len(encoder_input)*0.2)
print('테스트 데이터의 수 :', n_of_val)
# Out:
# 테스트 데이터의 수 : 17557

# %%
encoder_input_train = encoder_input[:-n_of_val]
decoder_input_train = decoder_input[:-n_of_val]
decoder_target_train = decoder_target[:-n_of_val]

encoder_input_test = encoder_input[-n_of_val:]
decoder_input_test = decoder_input[-n_of_val:]
decoder_target_test = decoder_target[-n_of_val:]

print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :', len(decoder_input_train))
print('테스트 데이터의 개수 :', len(encoder_input_test))
print('테스트 레이블의 개수 :', len(decoder_input_test))
# Out:
# 훈련 데이터의 개수 : 70230
# 훈련 레이블의 개수 : 70230
# 테스트 데이터의 개수 : 17557
# 테스트 레이블의 개수 : 17557

# %% [markdown]
# Step 2.3. 정수 인코딩

# %%
def src_tokenizer(text): # 토크나이저 정의
    text = text.lower()  # 소문자로 변환
    text = re.sub(r"[^a-zA-Z0-9]+", " ", text)  # 특수문자 제거
    return text.split()  # 공백 기준 토큰화

def build_vocab(texts):
    vocab = {"<PAD>": 0, "<UNK>": 1}  # 패딩과 UNK 토큰 추가
    word_counter = Counter()

    for text in texts:
        word_counter.update(src_tokenizer(text))  # 단어 빈도수 계산

    # 단어 집합 생성 (빈도가 높은 순서대로)
    for word, _ in word_counter.most_common():
        if word not in vocab:
            vocab[word] = len(vocab)

    return vocab

src_vocab = build_vocab(encoder_input_train) # 입력된 데이터로부터 단어 집합 생성
print('=3')
# Out:
# =3

# %%
threshold = 7

# 전처리된 데이터 사용
text_data = data['text'].tolist()
summary_data = data['headlines'].tolist()
# 단어 빈도수 계산
word_counter = Counter()
for text in text_data:
    word_counter.update(text.split())

total_cnt = len(word_counter)  # 전체 단어 개수
total_freq = sum(word_counter.values())  # 전체 단어 등장 횟수
rare_cnt = sum(1 for count in word_counter.values() if count < threshold)  # 희귀 단어 개수
rare_freq = sum(count for count in word_counter.values() if count < threshold)  # 희귀 단어 등장 횟수

# 희귀 단어를 제외한 단어 사전 구축
vocab = {"<PAD>": 0, "<UNK>": 1}  # 패딩 및 미등록 단어 추가
word_index = {word: idx + 2 for idx, (word, count) in enumerate(word_counter.items()) if count >= threshold}

print('단어 집합(vocabulary)의 크기 :', total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 72533
# 등장 빈도가 6번 이하인 희귀 단어의 수: 49255
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 23278
# 단어 집합에서 희귀 단어의 비율: 67.90702163153324
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 3.24995594541147

# %%
src_vocab_size = 24500

def build_limited_vocab(texts, vocab_size):
    vocab = {"<PAD>": 0, "<UNK>": 1}  # 패딩과 UNK 토큰 추가
    word_counter = Counter()

    for text in texts:
        word_counter.update(src_tokenizer(text))  # 단어 빈도수 계산

    # 빈도가 높은 상위 vocab_size - 2개 단어만 선택 (PAD, UNK 포함)
    for word, _ in word_counter.most_common(vocab_size - 2):
        vocab[word] = len(vocab)

    return vocab

src_vocab = build_limited_vocab(encoder_input_train, src_vocab_size)
print('=3')
# Out:
# =3

# %%
def text_to_sequence(texts, vocab):
    sequences = []
    for text in texts:
        sequence = [vocab.get(word, vocab["<UNK>"]) for word in src_tokenizer(text)]
        sequences.append(sequence)
    return sequences

# 텍스트 데이터 정수 시퀀스로 변환
encoder_input_train_seq = text_to_sequence(encoder_input_train, src_vocab)
encoder_input_test_seq = text_to_sequence(encoder_input_test, src_vocab)

# 잘 진행되었는지 샘플 출력
print(encoder_input_train_seq[:3])
print(encoder_input_test_seq[:3])
# Out:
# [[7, 17, 123, 43, 65, 629, 17, 3701, 2657, 619, 1014, 1537, 433, 5422, 1537, 10, 275, 2501, 358, 3610, 7, 1, 15075, 43, 76, 2657, 2, 1537, 1616, 476, 261, 1279, 710, 7, 413], [22728, 77, 10, 2244, 141, 10568, 8705, 516, 421, 4860, 34, 1, 77, 3995, 1729, 188, 3963, 2757, 5117, 9216, 1898, 5959, 664, 5506, 9392, 4382, 144, 1781, 900, 1005, 157, 2, 421, 640, 679, 411], [128, 5704, 2634, 35, 111, 4991, 37, 949, 3253, 2894, 59, 63, 1234, 35, 3063, 4670, 419, 59, 1319, 2133, 17, 360, 1441, 1870, 2101, 1167, 1090, 187, 106, 1234, 11772, 37, 4670]]
# [[428, 444, 28, 20770, 10290, 193, 54, 789, 478, 2781, 1145, 1664, 55, 4132, 1171, 12, 193, 1470, 1303, 3050, 7604, 457, 2548, 116, 112, 183, 242, 786, 310, 136, 632, 17107], [8600, 8016, 627, 44, 7755, 8287, 172, 1132, 1315, 387, 556, 23, 77, 2952, 1295, 136, 2682, 12, 6147, 3311, 110, 112, 1062, 12219, 349, 1691, 10372, 533, 8287, 2801, 1540, 54, 868, 281, 8600], [14, 3234, 3603, 3860, 496, 3936, 57, 1024, 355, 1872, 11, 494, 2855, 108, 202, 1453, 29, 169, 3603, 672, 56, 2, 11811, 1006, 1453, 862, 3788, 1024, 834, 15871, 609, 1182]]

# %%
def tar_tokenizer(text):
    text = text.lower()  # 소문자로 변환
    text = re.sub(r"[^a-zA-Z0-9]+", " ", text)  # 특수문자 제거
    return text.split()  # 공백 기준 토큰화

tar_vocab = build_vocab(decoder_input_train)
print('=3')
# Out:
# =3

# %%
threshold = 6

word_counter = Counter()
for text in decoder_input_train:
    word_counter.update(tar_tokenizer(text))  # 각 문장의 단어 빈도 계산

# 전체 단어 개수 및 등장 빈도 계산
total_cnt = len(word_counter)  # 전체 단어 개수
total_freq = sum(word_counter.values())  # 전체 단어 등장 횟수
rare_cnt = sum(1 for count in word_counter.values() if count < threshold)  # 희귀 단어 개수
rare_freq = sum(count for count in word_counter.values() if count < threshold)  # 희귀 단어 등장 횟수

print('단어 집합(vocabulary)의 크기 :', total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 28398
# 등장 빈도가 5번 이하인 희귀 단어의 수: 18710
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 9688
# 단어 집합에서 희귀 단어의 비율: 65.8849214733432
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 6.489687224860355

# %%
tar_vocab_size = 10300
tar_vocab = build_limited_vocab(decoder_input_train + decoder_target_train, tar_vocab_size)

# 텍스트 시퀀스를 정수 시퀀스로 변환
decoder_input_train_seq = text_to_sequence(decoder_input_train, tar_vocab)
decoder_target_train_seq = text_to_sequence(decoder_target_train, tar_vocab)
decoder_input_test_seq = text_to_sequence(decoder_input_test, tar_vocab)
decoder_target_test_seq = text_to_sequence(decoder_target_test, tar_vocab)

# 잘 변환되었는지 확인
print('input')
print('input ',decoder_input_train_seq[:5])
print('target')
print('decoder ',decoder_target_train_seq[:5])
# Out:
# input
# input  [[2, 463, 71, 2084, 113, 1948, 3451, 15], [2, 31, 20, 2769, 1406, 127, 1, 31, 6128], [2, 888, 272, 6786, 69, 537, 1165, 632, 18], [2, 1111, 294, 8, 8338, 3723, 234, 837, 90], [2, 7053, 1542, 143, 128, 1284, 503, 692]]
# target
# decoder  [[463, 71, 2084, 113, 1948, 3451, 15, 3], [31, 20, 2769, 1406, 127, 1, 31, 6128, 3], [888, 272, 6786, 69, 537, 1165, 632, 18, 3], [1111, 294, 8, 8338, 3723, 234, 837, 90, 3], [7053, 1542, 143, 128, 1284, 503, 692, 3]]

# %%
drop_train = [index for index, sentence in enumerate(decoder_input_train) if len(sentence) == 1]
drop_test = [index for index, sentence in enumerate(decoder_input_test) if len(sentence) == 1]

print('삭제할 훈련 데이터의 개수 :', len(drop_train))
print('삭제할 테스트 데이터의 개수 :', len(drop_test))

encoder_input_train = [sentence for index, sentence in enumerate(encoder_input_train) if index not in drop_train]
decoder_input_train = [sentence for index, sentence in enumerate(decoder_input_train) if index not in drop_train]
decoder_target_train = [sentence for index, sentence in enumerate(decoder_target_train) if index not in drop_train]

encoder_input_test = [sentence for index, sentence in enumerate(encoder_input_test) if index not in drop_test]
decoder_input_test = [sentence for index, sentence in enumerate(decoder_input_test) if index not in drop_test]
decoder_target_test = [sentence for index, sentence in enumerate(decoder_target_test) if index not in drop_test]

print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :', len(decoder_input_train))
print('테스트 데이터의 개수 :', len(encoder_input_test))
print('테스트 레이블의 개수 :', len(decoder_input_test))
# Out:
# 삭제할 훈련 데이터의 개수 : 0
# 삭제할 테스트 데이터의 개수 : 0
# 훈련 데이터의 개수 : 70230
# 훈련 레이블의 개수 : 70230
# 테스트 데이터의 개수 : 17557
# 테스트 레이블의 개수 : 17557

# %% [markdown]
# Step 2.4 패딩

# %%
from torch.nn.utils.rnn import pad_sequence

# 텐서 변환 함수 (리스트 → PyTorch 텐서)
def convert_to_tensor(sequences):
    return [torch.tensor(seq, dtype=torch.long) for seq in sequences]

# 패딩 적용 함수 (PyTorch `pad_sequence()` 활용)
def pad_sequences_pytorch(sequences, maxlen, padding_value=0):
    sequences = convert_to_tensor(sequences)  # 리스트를 텐서로 변환
    padded_seqs = pad_sequence(sequences, batch_first=True, padding_value=padding_value)  # 패딩 적용
    return padded_seqs[:, :maxlen]  # maxlen 길이로 자르기 (최대 길이 초과 방지)

# 패딩 적용
encoder_input_train = pad_sequences_pytorch(encoder_input_train_seq, maxlen=text_max_len)
encoder_input_test = pad_sequences_pytorch(encoder_input_test_seq, maxlen=text_max_len)
decoder_input_train = pad_sequences_pytorch(decoder_input_train_seq, maxlen=summary_max_len)
decoder_target_train = pad_sequences_pytorch(decoder_target_train_seq, maxlen=summary_max_len)
decoder_input_test = pad_sequences_pytorch(decoder_input_test_seq, maxlen=summary_max_len)
decoder_target_test = pad_sequences_pytorch(decoder_target_test_seq, maxlen=summary_max_len)

print('=3')
# Out:
# =3

# %% [markdown]
# Step 3.1 모델설계

# %%
import torch.nn as nn
import torch.nn.functional as F

# 인코더 설계 시작
embedding_dim = 128
hidden_size = 256
src_vocab_size = len(src_vocab)  # 단어 집합 크기

# 인코더
class Encoder(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_size, num_layers=3, dropout=0.4):
        super(Encoder, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(
            embedding_dim, hidden_size, num_layers=num_layers,
            dropout=dropout, batch_first=True
        )

    def forward(self, x): # 인코더의 임베딩 층
        embedded = self.embedding(x)
        output, (hidden, cell) = self.lstm(embedded)  # LSTM 실행
        return output, hidden, cell

# 인코더 모델 생성
encoder = Encoder(src_vocab_size, embedding_dim, hidden_size, num_layers=3, dropout=0.4)

# %%
# 디코더 설계
class Decoder(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_size, dropout=0.4, num_layers=3):
        super(Decoder, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(
            embedding_dim, hidden_size, num_layers=num_layers, dropout=dropout,
            batch_first=True
        )

    def forward(self, x, hidden, cell): # 디코더의 임베딩 층
        embedded = self.embedding(x)
        output, (hidden, cell) = self.lstm(embedded, (hidden, cell))  # 초기 상태를 인코더에서 전달받음
        return output, hidden, cell

# 디코더 모델 생성
decoder = Decoder(tar_vocab_size, embedding_dim, hidden_size, num_layers=3, dropout=0.4)

# %%
# 디코더의 출력층
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder, vocab_size):
        super(Seq2Seq, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.softmax_layer = nn.Linear(hidden_size, vocab_size)  # 출력층 정의

    def forward(self, encoder_input, decoder_input):
        # 인코더 실행
        encoder_output, hidden, cell = self.encoder(encoder_input)

        # 디코더 실행
        decoder_output, _, _ = self.decoder(decoder_input, hidden, cell)

        # 출력층 적용 (Softmax는 Loss 내부에서 적용되므로 생략 가능)
        output = self.softmax_layer(decoder_output)
        return output

# 모델 정의
model = Seq2Seq(encoder, decoder, tar_vocab_size)
print(model)

# %% [markdown]
# Step 3.2. Attention 매커니즘

# %%
class Attention_dot(nn.Module):
    def __init__(self, hidden_size):
        super(Attention_dot, self).__init__()
        self.attn = nn.Linear(hidden_size, hidden_size)  # 어텐션 가중치
        self.v = nn.Linear(hidden_size, 1, bias=False)  # 어텐션 가중치 벡터

    def forward(self, decoder_output, encoder_outputs):
        attn_weights = torch.bmm(decoder_output, encoder_outputs.transpose(1, 2))
        attn_weights = F.softmax(attn_weights, dim=-1)  # 어텐션 가중치 정규화
        attn_out = torch.bmm(attn_weights, encoder_outputs)

        return attn_out

class Seq2SeqWithAttention(nn.Module):
    def __init__(self, encoder, decoder, vocab_size, hidden_size):
        super(Seq2SeqWithAttention, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.attention = Attention_dot(hidden_size)
        self.concat = nn.Linear(hidden_size * 2, hidden_size)  # 어텐션 결합
        self.output_layer = nn.Linear(hidden_size, vocab_size)  # 최종 출력층

    def forward(self, encoder_input, decoder_input):
        encoder_outputs, hidden, cell = self.encoder(encoder_input)
        decoder_outputs, _, _ = self.decoder(decoder_input, hidden, cell)

        # 어텐션 적용
        attn_out = self.attention(decoder_outputs, encoder_outputs)

        # 어텐션 결과와 디코더 출력 연결
        decoder_concat_output = torch.cat((decoder_outputs, attn_out), dim=-1)

        # 어텐션 결합 후 최종 출력
        decoder_concat_output = torch.tanh(self.concat(decoder_concat_output))
        output = self.output_layer(decoder_concat_output)

        return output

# 모델 생성
model = Seq2SeqWithAttention(encoder, decoder, tar_vocab_size, hidden_size)
print(model)
# Out:
# Seq2SeqWithAttention(
#   (encoder): Encoder(
#     (embedding): Embedding(24500, 128)
#     (lstm): LSTM(128, 256, num_layers=3, batch_first=True, dropout=0.4)
#   )
#   (decoder): Decoder(
#     (embedding): Embedding(10300, 128)
#     (lstm): LSTM(128, 256, num_layers=3, batch_first=True, dropout=0.4)
#   )
#   (attention): Attention_dot(
#     (attn): Linear(in_features=256, out_features=256, bias=True)
#     (v): Linear(in_features=256, out_features=1, bias=False)
#   )
#   (concat): Linear(in_features=512, out_features=256, bias=True)
#   (output_layer): Linear(in_features=256, out_features=10300, bias=True)
# )

# %% [markdown]
# Step 3.3. 모델훈련

# %%
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
model.to(device)

# Hyperparameters
batch_size = 256
epochs = 50
learning_rate = 0.001
patience = 2

# 손실 함수 & 옵티마이저
criterion = nn.CrossEntropyLoss(ignore_index=0)  # 패딩 토큰 무시
optimizer = optim.AdamW(model.parameters(), lr=learning_rate)

# PyTorch DataLoader 설정
train_dataset = TensorDataset(encoder_input_train, decoder_input_train, decoder_target_train)
test_dataset = TensorDataset(encoder_input_test, decoder_input_test, decoder_target_test)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Using device: cuda

# %%
train_losses = []
val_losses = []

# 학습 함수
def train_model(model, train_loader, test_loader, criterion, optimizer, epochs, patience):
    model.train()
    best_val_loss = float('inf')
    early_stop_counter = 0

    for epoch in range(epochs):
        total_loss = 0

        for encoder_input, decoder_input, target in train_loader:
            optimizer.zero_grad()

            # 정수형 변환
            encoder_input = encoder_input.to(device).long()
            decoder_input = decoder_input.to(device).long()
            target = target.to(device).long()

            # 모델 실행
            output = model(encoder_input, decoder_input)
            output = output.view(-1, output.shape[-1])
            target = target.view(-1)

            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        avg_loss = total_loss / len(train_loader)
        train_losses.append(avg_loss)

        # Validation loss 계산
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for encoder_input, decoder_input, target in test_loader:
                encoder_input = encoder_input.to(device).long()
                decoder_input = decoder_input.to(device).long()
                target = target.to(device).long()

                output = model(encoder_input, decoder_input)
                output = output.view(-1, output.shape[-1])
                target = target.view(-1)
                loss = criterion(output, target)

                val_loss += loss.item()

        val_loss /= len(test_loader)
        val_losses.append(val_loss)
        print(f"Epoch {epoch+1}/{epochs} | Train Loss: {avg_loss:.4f} | Val Loss: {val_loss:.4f}")

        # Early Stopping 조건
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            early_stop_counter = 0
        else:
            early_stop_counter += 1

        if early_stop_counter >= patience:
            print(f"Early stopping triggered at epoch {epoch+1}")
            break

        model.train()

# %%
# %%time
# 학습 실행

train_model(model, train_loader, test_loader, criterion, optimizer, epochs=epochs, patience=patience)
# Out:
# Epoch 1/50 | Train Loss: 7.4197 | Val Loss: 7.1894
# Epoch 2/50 | Train Loss: 7.1622 | Val Loss: 6.9216
# Epoch 3/50 | Train Loss: 6.7256 | Val Loss: 6.3695
# Epoch 4/50 | Train Loss: 6.1919 | Val Loss: 5.9977
# Epoch 5/50 | Train Loss: 5.8245 | Val Loss: 5.7690
# Epoch 6/50 | Train Loss: 5.5396 | Val Loss: 5.5955
# Epoch 7/50 | Train Loss: 5.2933 | Val Loss: 5.4554
# Epoch 8/50 | Train Loss: 5.0730 | Val Loss: 5.3498
# Epoch 9/50 | Train Loss: 4.8749 | Val Loss: 5.2665
# Epoch 10/50 | Train Loss: 4.6884 | Val Loss: 5.2013
# Epoch 11/50 | Train Loss: 4.5221 | Val Loss: 5.1659
# Epoch 12/50 | Train Loss: 4.3682 | Val Loss: 5.1288
# Epoch 13/50 | Train Loss: 4.2263 | Val Loss: 5.1095
# Epoch 14/50 | Train Loss: 4.0948 | Val Loss: 5.0990
# Epoch 15/50 | Train Loss: 3.9689 | Val Loss: 5.0898
# Epoch 16/50 | Train Loss: 3.8528 | Val Loss: 5.0970
# Epoch 17/50 | Train Loss: 3.7433 | Val Loss: 5.0968
# Early stopping triggered at epoch 17
# CPU times: user 6min 25s, sys: 1.15 s, total: 6min 26s
# Wall time: 6min 30s

# %%
plt.plot(range(len(train_losses)), train_losses, label='Train Loss')
plt.plot(range(len(val_losses)), val_losses, label='Validation Loss')
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.show()

# %% [markdown]
# Step 3.4. 인퍼런스 모델구현

# %%
src_index_to_word = {idx: word for word, idx in src_vocab.items()} # 원문 단어 집합에서 정수 -> 단어를 얻음
tar_word_to_index = tar_vocab # 요약 단어 집합에서 단어 -> 정수를 얻음
tar_index_to_word = {idx: word for word, idx in tar_vocab.items()} # 요약 단어 집합에서 정수 -> 단어를 얻음

print('=3')
# Out:
# =3

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
decoder.to(device)

# 인코더 설계
def encode_input(encoder, input_seq):
    encoder_outputs, hidden, cell = encoder(input_seq)
    return encoder_outputs, hidden, cell

# 이전 시점의 상태들을 저장하는 텐서
num_layers = 3  # 디코더 LSTM 레이어 개수 (설정에 맞춰 조정)
batch_size = 1

decoder_state_input_h = torch.zeros((num_layers, batch_size, hidden_size), dtype=torch.float, device=device)
decoder_state_input_c = torch.zeros((num_layers, batch_size, hidden_size), dtype=torch.float, device=device)
decoder_input = torch.zeros((batch_size, 1), dtype=torch.long, device=device)

dec_emb2 = decoder.embedding(decoder_input)

# 문장의 다음 단어를 예측하기 위해서 초기 상태(initial_state)를 이전 시점의 상태로 사용. 이는 뒤의 함수 decode_sequence()에 구현
# 훈련 과정에서와 달리 LSTM의 리턴하는 은닉 상태와 셀 상태인 state_h와 state_c를 버리지 않음.
decoder_outputs2, state_h2, state_c2 = decoder(decoder_input, decoder_state_input_h, decoder_state_input_c)

print('=3')
# Out:
# =3

# %%
class DecoderWithAttention(nn.Module):
    def __init__(self, decoder, attention, hidden_size, vocab_size):
        super(DecoderWithAttention, self).__init__()
        self.decoder = decoder  # 기존 디코더
        self.attention = attention  # 어텐션 레이어
        self.concat = nn.Linear(hidden_size * 2, hidden_size)  # 어텐션 결합 레이어
        self.output_layer = nn.Linear(hidden_size, vocab_size)  # 최종 출력층
        self.softmax = nn.Softmax(dim=-1)  # 소프트맥스

    def forward(self, decoder_inputs, decoder_hidden_state, decoder_state_h, decoder_state_c):
        # 디코더 실행
        decoder_outputs, state_h, state_c = self.decoder(decoder_inputs, decoder_state_h, decoder_state_c)

        # 어텐션 적용
        attn_out = self.attention(decoder_outputs, decoder_hidden_state)

        # 어텐션과 디코더 출력 결합
        decoder_concat_output = torch.cat((decoder_outputs, attn_out), dim=-1)
        decoder_concat_output = torch.tanh(self.concat(decoder_concat_output))

        # 최종 출력층 적용
        decoder_outputs2 = self.softmax(self.output_layer(decoder_concat_output))

        return decoder_outputs2, state_h, state_c

# 기존 Attention 클래스 사용
attention_layer = Attention_dot(hidden_size)

# 디코더 모델 생성
decoder_model = DecoderWithAttention(decoder, attention_layer, hidden_size, tar_vocab_size)
print('=3')
# Out:
# =3

# %%
def decode_sequence(input_seq, encoder, decoder, tar_word_to_index, tar_index_to_word, text_max_len, summary_max_len, device):
    # 입력을 PyTorch Tensor로 변환
    input_seq = torch.tensor(input_seq, dtype=torch.long, device=device)

    # 인코더 실행하여 초기 상태(hidden, cell) 얻기
    with torch.no_grad():
        e_out, e_h, e_c = encoder(input_seq)

    e_out = e_out.repeat(1, text_max_len, 1)  # 차원 조정 (np.tile 대신 repeat 사용)

    # <SOS>에 해당하는 토큰 생성
    target_seq = torch.zeros((1, 1), dtype=torch.long, device=device)
    target_seq[0, 0] = tar_word_to_index['sostoken']

    stop_condition = False
    decoded_sentence = ''

    while not stop_condition:
        # 디코더 실행
        with torch.no_grad():
            output_tokens, h, c = decoder(target_seq, e_h, e_c)

        # 가장 높은 확률을 가진 단어 선택
        sampled_token_index = torch.argmax(output_tokens[0, -1, :]).item()
        sampled_token = tar_index_to_word[sampled_token_index]

        if sampled_token != 'eostoken':
            decoded_sentence += ' ' + sampled_token

        # 종료 조건: <eos>에 도달하거나 최대 길이를 초과하면 중단
        if sampled_token == 'eostoken' or len(decoded_sentence.split()) >= (summary_max_len - 1):
            stop_condition = True

        # 길이가 1인 타겟 시퀀스를 업데이트
        target_seq = torch.zeros((1, 1), dtype=torch.long, device=device)
        target_seq[0, 0] = sampled_token_index

        # 상태 업데이트
        e_h, e_c = h, c

    return decoded_sentence
print("=3")
# Out:
# =3

# %% [markdown]
# Step 4. 모델 테스트

# %%
# 원문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2text(input_seq):
    temp = ''
    for i in input_seq:
        key = int(i.item())  # PyTorch Tensor → int 변환
        if key != 0:  # 패딩(0) 제외
            temp = temp + src_index_to_word.get(key, "<UNK>") + ' '  # 안전한 조회
    return temp.strip()

# 요약문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2summary(input_seq):
    temp = ''
    for i in input_seq:
        key = int(i.item())  # PyTorch Tensor → int 변환
        if key != 0 and key != tar_word_to_index['sostoken'] and key != tar_word_to_index['eostoken']:
            temp = temp + tar_index_to_word.get(key, "<UNK>") + ' '  # 안전한 조회
    return temp.strip()  # 양쪽 공백 제거

print('=3')
# Out:
# =3

# %%
# %%time
for i in range(50, 100):
    print("원문 :", seq2text(encoder_input_test[i]))
    print("실제 요약 :", seq2summary(decoder_input_test[i]))
    input_seq = torch.tensor(encoder_input_test[i], dtype=torch.long, device=device).unsqueeze(0)
    print("예측 요약 :", decode_sequence(input_seq, encoder, decoder, tar_word_to_index, tar_index_to_word, text_max_len, summary_max_len, device))
    print("\n")
# Out:
# 원문 : bangalore university issued warning students <UNK> undergraduate courses offered affiliated colleges warning issued colleges put advertisements admissions new course combinations including <UNK> colleges give false information cheat students university officials said
# 실제 요약 : <UNK> <UNK> courses bangalore university
# 예측 요약 :  us test using announces train russia shares
#
#
# 원문 : mumbai based web mobile browser testing platform <UNK> raised million series funding round us based venture capital firm accel partners vc firm also picked minority equity stake startup company said founded startup enables users test local servers cloud browsers
# 실제 요약 : website testing platform <UNK> raises million
# 예측 요약 :  billion women open open open open open
#
#
# 원문 : telugu desam party contest lok sabha assembly elections odisha next year tdp state unit charge rajesh <UNK> said <UNK> reportedly said tdp field candidates assembly constituencies five lok sabha seats odisha tdp focus southern region odisha telugu spoken people added
# 실제 요약 : tdp contest lok sabha assembly polls odisha
# 예측 요약 :  us women two announces firm firm father
#
#
# 원문 : maharashtra governor vidyasagar rao sacked mumbai university vice chancellor sanjay deshmukh gross negligence deshmukh held responsible failing implement screen marking system declaring exam results within time limit results declared three months record requests evaluation received varsity
# 실제 요약 : mumbai university vc sacked delay exam results
# 예측 요약 :  indian women using announces train russia shares
#
#
# 원문 : presenting union budget finance minister arun jaitley thursday announced president monthly salary increased lakh earlier lakh vice president monthly salary increased lakh lakh government proposed law automatically revise mps salaries every years
# 실제 요약 : president monthly salary go lakh lakh
# 예측 요약 :  polls women two two made russia two
#
#
# 원문 : reacting armed guard taking <UNK> downing street houses uk pm residence user tweeted surely <UNK> always given much protection others wrote vision post brexit future want <UNK> need fight guns <UNK> feels walk past sibling snacks
# 실제 요약 : twitter reacts armed guard taking <UNK> <UNK>
# 예측 요약 :  us becomes us singh president accused harassment
#
#
# 원문 : extending support andhra pradesh leaders demanding special category status state congress president rahul gandhi tuesday said party fulfil demand voted power general elections ruling tdp part bjp led nda alliance also protesting centre alleging neglected andhra pradesh
# 실제 요약 : give special status andhra voted power rahul
# 예측 요약 :  polls women men accused two post post
#
#
# 원문 : indian tennis player sania mirza posted picture medals asian games mirza participating edition wrote first time since competing asian games representing country little sad feeling nostalgic sania wrote
# 실제 요약 : sania mirza shares photo asian games medals
# 예측 요약 :  made security suicide two post suicide suicide
#
#
# 원문 : saudi arabia united arab emirates pledged combined million women entrepreneurs fund proposed us president donald trump daughter ivanka trump according reports fund ivanka first proposed germany trip run world bank help female entrepreneurs capital networking resources start businesses
# 실제 요약 : saudi uae pledge million ivanka trump proposed
# 예측 요약 :  army test flight flight flight china win
#
#
# 원문 : voting member madhya pradesh assembly member mizoram assembly began today madhya pradesh bjp power since around polling booths set would entirely operated women whereas mizoram congress power since lal thanhawla chief minister
# 실제 요약 : voting madhya pradesh mizoram assembly elections begins
# 예측 요약 :  us women chinese ram ram home home
#
#
# 원문 : railway bridges india years old minister state railways rajen gohain informed lok sabha wednesday asserting age bridge directly related physical condition minister said bridges inspected twice year indian railways total lakh bridges
# 실제 요약 : railway <UNK> india years old
# 예측 요약 :  polls women two post post post two
#
#
# 원문 : iit guwahati scientists synthesised mats made silk proteins <UNK> glass fibres could assist growth bone cells repair worn joints arthritis patients mats bond native tissue eventually degrade new tissue formed place lab tests artificial tissue formed efficiently within two weeks researchers said
# 실제 요약 : iit scientists develop silk <UNK> could treat
# 예측 요약 :  billion women post post back back back
#
#
# 원문 : twenty three time grand slam champion serena williams took social media open struggles <UNK> depression saying felt like good mom last week serena suffered career worst defeat last week wrote although every day life around much would like
# 실제 요약 : felt good mom serena <UNK> <UNK>
# 예측 요약 :  us becomes us singh two firm firm
#
#
# 원문 : woman hyderabad stranded kuwait rescued indian embassy officials mother wrote letter external affairs minister sushma swaraj woman claimed agent lured promise job <UNK> however said forced work housemaid tortured employers
# 실제 요약 : woman rescued kuwait mom seeks swaraj help
# 예측 요약 :  us women us two chinese air air
#
#
# 원문 : per reports actress deepika padukone approached star opposite prabhas upcoming bollywood film makers also said considering alia bhatt katrina kaif deepika rejects film earlier prabhas said <UNK> script three years ago love story post saaho
# 실제 요약 : deepika approached star opposite prabhas film report
# 예측 요약 :  army law flight flight reports singh study
#
#
# 원문 : year old man florida us arrested allegedly attacking neighbour <UNK> word kindness written victim another neighbour walked bryan stewart house tell keep noise accused stewart carried attack heard threatening kill someone kindness
# 실제 요약 : us man attacks neighbour <UNK> named <UNK>
# 예측 요약 :  us women offers president train study shares
#
#
# 원문 : maharashtra based couple filed police complaint picture shared social media account holi circulated meme woman posted photograph husband left coloured <UNK> chest would never thought would <UNK> cheap manner woman said
# 실제 요약 : couple files complaint holi pic circulated meme
# 예측 요약 :  indian women using announces train train shares
#
#
# 원문 : delay joint military drills us depend north korea behaviour south korean official said wednesday north korea termed recent us south korea drills provocation accusing us begging nuclear war staging military exercise us south korea staged drills north korea nuclear programme
# 실제 요약 : could delay drills <UNK> north behaviour korea
# 예측 요약 :  polls women men men two men father
#
#
# 원문 : india proposed introduce million retaliatory tariffs list items imported us india asked us exempt tariffs steel aluminium us rejected request india notified world trade organisation list including apples <UNK> motorcycles intends impose tariffs
# 실제 요약 : india proposes mn retaliatory tariffs us products
# 예측 요약 :  army test india flight flight china china
#
#
# 원문 : india first indigenous sniper rifle launched wednesday rifle factory west bengal <UNK> worth lakh weighing kg rifle shooting range metres one advantages reportedly abundance ammunition factory received orders crpf police forces haryana rajasthan
# 실제 요약 : india gets first indigenous <UNK> rifle
# 예측 요약 :  polls women two two russia russia russia
#
#
# 원문 : canadian woman slammed british airways claiming seven year old daughter left bleeding bitten bugs flight woman added given different seats even raising issue crew twice meanwhile british airways spokesman said airline apologised woman family
# 실제 요약 : british airways slammed bed bugs plane seats
# 예측 요약 :  billion women suicide suicide accused singh singh
#
#
# 원문 : recently revealed memo warning employees leak confidential details apple said apple caught <UNK> arrested giving example employee leaked information apple said thought would discovered <UNK> whether employees contractors get caught getting caught faster ever apple pointed
# 실제 요약 : caught <UNK> arrested apple
# 예측 요약 :  us test chinese ram home home home
#
#
# 원문 : saudi arabia general security division sunday allowed women aged apply rank soldier part vision social program launched crown prince mohammad bin salman however saudi women fulfil conditions including mandatory medical check good weight height ratio
# 실제 요약 : saudi arabia allows women join armed forces
# 예측 요약 :  indian women using announces train train shares
#
#
# 원문 : rjd leader bhai <UNK> monday refused remove red beacon atop car said order bihar government cabinet decided bihar follow decision delhi cabinet government pass order follow rule said
# 실제 요약 : rjd leader refuses remove red beacon car
# 예측 요약 :  polls women two two suicide suicide suicide
#
#
# 원문 : government preparing digital atlas flood prone areas give warnings real time information rise water levels reports said help local administrations reduce damage property loss life floods reports added flood warning system india currently based water level forecasting
# 실제 요약 : govt plans digital <UNK> flood prone areas
# <timed exec>:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /tmp/ipykernel_170/366614501.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   input_seq = torch.tensor(input_seq, dtype=torch.long, device=device)
# 예측 요약 :  polls women post post post post post
#
#
# 원문 : many whales died washed ashore western australia rescue operations underway save remaining authorities warned public avoid area dying animals could attract sharks closer shore largest mass <UNK> whales region happened long <UNK> pilot whales washed ashore
# 실제 요약 : whales die mass <UNK> australian beach
# 예측 요약 :  flight offers flight train yr home study
#
#
# 원문 : australian court granted queensland woman right use dead boyfriend sperm children woman relationship man three years killed notably illegal queensland take store transport use ivf man sperm without written consent
# 실제 요약 : aus woman allowed baby using dead partner
# 예측 요약 :  billion women two two post post back
#
#
# 원문 : talking social media platforms like facebook twitter us congressman steve king suggested converting large <UNK> organisations public utilities said hearing filtering practices social media platforms king suggestion followed inquiries facebook algorithm right wing website losing reach social media
# 실제 요약 : turn facebook twitter public <UNK> us <UNK>
# 예측 요약 :  us becomes chinese air air air air
#
#
# 원문 : toshiba us nuclear unit <UNK> filed bankruptcy shareholder company meeting said toshiba become laughing stock around world clue going meeting saw shareholders vent ceo satoshi <UNK> toshiba shareholders agreed split nand flash memory unit raise money cover <UNK> charges
# 실제 요약 : <UNK> become laughing stock shareholder tells ceo
# 예측 요약 :  us women mn announces train air leader
#
#
# 원문 : shia <UNK> starrer man released march earned opening weekend uk film shown one cinema hall given video demand release senior media analyst paul <UNK> wrote poor shia opening could guinness world records something
# 실제 요약 : shia le <UNK> film earns first weekend
# 예측 요약 :  polls women take train train russia singh
#
#
# 원문 : following incidents violence filing nominations west bengal panchayat polls state congress chief <UNK> chowdhury demanded president rule state without imposing president rule one able exercise democratic right chowdhury said bjp also complained party workers attacked trying file nominations
# 실제 요약 : need president rule wb cong panchayat poll
# 예측 요약 :  us women us two two firm firm
#
#
# 원문 : scuffle broke bjp bsp workers uttar pradesh one newly elected corporators latter took oath urdu aligarh municipal corporation adding people objected raised slogans ceremony aligarh district magistrate said authorities probe recordings ceremony take action accordingly
# 실제 요약 : bjp bsp workers clash corporator takes oath
# 예측 요약 :  court offers flight train <UNK> yr home
#
#
# 원문 : much road <UNK> put delhi ncr non standard wrongfully installed according survey conducted institute road traffic education many accidents recent times could averted road <UNK> mark <UNK> president dr rohit <UNK> said
# 실제 요약 : road <UNK> delhi ncr incorrect traffic survey
# 예측 요약 :  us offers flight train russia yr home
#
#
# 원문 : grenade found well delhi red fort thursday evening prompting team national security guard swing action nsg safely removed grenade red fort preliminary inquiry suggests old grenade said jatin <UNK> dcp
# 실제 요약 : grenade found well delhi red fort
# 예측 요약 :  us women offers president train russia dead
#
#
# 원문 : marks spencer <UNK> suspended buying chicken uk sisters food group owned west <UNK> factory comes investigation guardian revealed supplier tampering food safety records <UNK> said commenced investigation claims workers factory changing slaughter dates poultry potentially making unsafe
# 실제 요약 : stops business chicken supplier hygiene issues
# 예측 요약 :  billion women two two post post back
#
#
# 원문 : stephen <UNK> vice president marvel jokingly said marvel makes indian content shah rukh khan said stories set different countries goal always use actors part world added try create characters real <UNK> indian culture
# 실제 요약 : srk indian content marvel makes jokes executive
# 예측 요약 :  us becomes us men firm firm two
#
#
# 원문 : school us city boston using nursery rhyme teach kindergarten students survive school shootings according reports lockdown poem supposed sung tune poem twinkle twinkle little star comes part measures tackle school shootings us
# 실제 요약 : <UNK> <UNK> teaches us kids survive school
# 예측 요약 :  us women using announces train train russia
#
#
# 원문 : colombia <UNK> rebels reportedly launch political party conference beginning sunday choose party name candidates next year general elections comes year old conflict colombian government <UNK> ended earlier month following final disarmament weapons rebels un
# 실제 요약 : colombia <UNK> rebels launch political party
# 예측 요약 :  us women flight win accused accused father
#
#
# 원문 : teaser rishi kapoor taapsee pannu starrer mulk released taapsee seen playing role lawyer named aarti mohammed rishi portray man named murad ali mohammed accused directed co produced anubhav sinha mulk scheduled release august
# 실제 요약 : teaser rishi kapoor taapsee pannu starrer mulk
# 예측 요약 :  us women president offers president train shares
#
#
# 원문 : <UNK> actress <UNK> ali sardar recently got trolled picture said someone expects look years ago something wrong someone people use photo technologies filters look different beautiful photos everyone else cannot said
# 실제 요약 : wrong expect look yrs ago <UNK> actress
# 예측 요약 :  us women us two chinese air air
#
#
# 원문 : diary late united states president john kennedy kept days journalist world war ii sold auction wednesday page diary kennedy suspected hitler dead stuff legends made expressing doubts united nations effectiveness
# 실제 요약 : john <UNK> <UNK> journalist sells crore
# 예측 요약 :  us women offers president train russia shares
#
#
# 원문 : maldives high commissioner ahmed mohamed said country wanted send special envoy india cancelled proposed visit informed dates suitable indian government comes reported maldives amid political crisis sent envoys friendly countries india
# 실제 요약 : wanted send envoy dates suit india maldives
# 예측 요약 :  polls security air ram air leader two
#
#
# 원문 : saif ali khan asked reporter wife kareena kapoor comeback responded saying asked question would probably thrown shoe according always around added kareena next seen film veere di wedding
# 실제 요약 : kareena throw shoe asked comeback saif
# 예측 요약 :  us women mn mn mn two two
#
#
# 원문 : filmmaker vikas bahl moved bombay high court crore defamation suit former phantom films partners anurag kashyap vikramaditya motwane bahl also sought direction hc restrain making statement media via social media bahl accused sexual harassment former employee phantom films
# 실제 요약 : vikas bahl files cr defamation suit anurag
# 예측 요약 :  court singh us co ram ram ram
#
#
# 원문 : chhattisgarh cm raman singh said india dharamshala people outside keep entering country speaking nrc issue singh said must deported people marked result eight year long protest assamese youth either lakh people prove identity go back
# 실제 요약 : india <UNK> chhattisgarh cm raman singh nrc
# 예측 요약 :  made women post post post post two
#
#
# 원문 : wake heightened tension two nations regarding kulbhushan jadhav case pakistan said india capable producing nuclear weapons india world fastest growing nuclear programme added pakistan statement regarding india enhancing nuclear capability come days reports suggested new delhi may <UNK> nuclear doctrine
# 실제 요약 : india <UNK> make nuclear weapons pakistan
# 예측 요약 :  polls security men two post post post
#
#
# 원문 : first meeting un general assembly comprising nations convened westminster central hall london england january meeting saw election belgium paul henri <UNK> first president general assembly established <UNK> <UNK> representative organ un
# 실제 요약 : first meeting united nations held years ago
# 예측 요약 :  us women flight win accused singh shares
#
#
# 원문 : microsoft president brad smith accused north korea carrying wannacry cyber attack hit two lakh computers across countries earlier year adding north korea used cyber tools stolen us national security agency smith said last six months world seen threats come life serious way
# 실제 요약 : korea carried wannacry cyber attack microsoft prez
# 예측 요약 :  polls women post two post post two
#
#
# 원문 : two men staged mock wedding <UNK> tamil nadu protest reopening state owned liquor shops state people earlier forced closure liquor outlets citing ill effects alcohol shops reopened recently protestors staging mock wedding saying alcoholic let women marry
# 실제 요약 : men marry protest <UNK> liquor shops tn
# 예측 요약 :  us women offers president train russia shares
#
#
# 원문 : university chinese city <UNK> offering weight loss course students whose body mass index higher year long course encourages students lose weight exercise diet control grade determined much weight lose university introduced course realising students gaining weight
# 실제 요약 : university offers weight loss course <UNK> students
# 예측 요약 :  flight test flight flight accused singh study
#
#
# CPU times: user 379 ms, sys: 9.98 ms, total: 389 ms
# Wall time: 391 ms

# %% [markdown]
# Step 5 Summa를 이용한 추출적 요약

# %%
import pandas as pd
import torch
from sklearn.model_selection import train_test_split
from summa.summarizer import summarize

# 1. 원본 데이터 다시 업로드 및 로드 (구두점과 대소문자가 그대로 있는 원본 데이터프레)
data = pd.read_csv('news_summary_more.csv', encoding='iso-8859-1')

train_df, test_df = train_test_split(data, test_size=0.2, random_state=42) 


# 50번부터 99번 샘플까지 비교 루프 실행
for i in range(50, 100):
    print(f"=== [Sample Index: {i}] ===")
    
    # ① 정제된 원문 (기존 코드)
    clean_text = seq2text(encoder_input_test[i])
    print("정제된 원문  :", clean_text)
    
    # ② 실제 정답 요약 (기존 코드)
    real_summary = seq2summary(decoder_input_test[i])
    print("실제 정답 요약:", real_summary)
    
    # ③ 딥러닝 모델의 예측 결과 (추상적 요약)
    input_seq = torch.tensor(encoder_input_test[i], dtype=torch.long, device=device).unsqueeze(0)
    abstract_summary = decode_sequence(input_seq, encoder, decoder, tar_word_to_index, tar_index_to_word, text_max_len,summary_max_len,device)
    print("예측(딥러닝)  :", abstract_summary)
    
    # ④ Summa 패키지를 이용한 결과 (추출적 요약)
    # 구두점이 살아있는 원래의 Text 문장을 가져옵니다.
    raw_text = test_df['text'].iloc[i] 
    
    # 본문이 짧으므로 최소 1~2문장이 나오도록 ratio를 0.4~0.5로 설정합니다.
    extractive_summary = summarize(raw_text, ratio=0.4)
    
    # 만약 원문이 너무 짧아 Summa 결과가 비어있다면, 원문의 첫 문장을 가져오도록 안전장치 설정
    if not extractive_summary.strip():
        extractive_summary = raw_text.split('.')[0] + '.'
        
    print("예측(Summa)   :", extractive_summary.strip())
    print("\n" + "-"*70 + "\n")
# Out:
# === [Sample Index: 50] ===
# 정제된 원문  : bangalore university issued warning students <UNK> undergraduate courses offered affiliated colleges warning issued colleges put advertisements admissions new course combinations including <UNK> colleges give false information cheat students university officials said
# 실제 정답 요약: <UNK> <UNK> courses bangalore university
# 예측(딥러닝)  :  us test using announces train russia shares
# 예측(Summa)   : Kareena Kapoor, while talking about her step-daughter Sara Ali Khan's Bollywood debut, said that she's sure Sara is going to rock the industry with her beauty and talent.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 51] ===
# 정제된 원문  : mumbai based web mobile browser testing platform <UNK> raised million series funding round us based venture capital firm accel partners vc firm also picked minority equity stake startup company said founded startup enables users test local servers cloud browsers
# 실제 정답 요약: website testing platform <UNK> raises million
# 예측(딥러닝)  :  billion women open open open open open
# 예측(Summa)   : Actress Sunny Leone, who celebrated her 36th birthday on Saturday, has said, "Daniel makes me feel special every day.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 52] ===
# 정제된 원문  : telugu desam party contest lok sabha assembly elections odisha next year tdp state unit charge rajesh <UNK> said <UNK> reportedly said tdp field candidates assembly constituencies five lok sabha seats odisha tdp focus southern region odisha telugu spoken people added
# 실제 정답 요약: tdp contest lok sabha assembly polls odisha
# 예측(딥러닝)  :  us women two announces firm firm father
# 예측(Summa)   : US-based scientists have developed an ultra-sensitive camera capable of sensing both colour and polarisation that mimics the eye of the mantis shrimp.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 53] ===
# 정제된 원문  : maharashtra governor vidyasagar rao sacked mumbai university vice chancellor sanjay deshmukh gross negligence deshmukh held responsible failing implement screen marking system declaring exam results within time limit results declared three months record requests evaluation received varsity
# 실제 정답 요약: mumbai university vc sacked delay exam results
# 예측(딥러닝)  :  indian women using announces train russia shares
# 예측(Summa)   : In a recent interview, Congress MP Divya Spandana said, "They (BJP) don't need WhatsApp and Twitter when they have PM (Narendra Modi) to spread fake news.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 54] ===
# 정제된 원문  : presenting union budget finance minister arun jaitley thursday announced president monthly salary increased lakh earlier lakh vice president monthly salary increased lakh lakh government proposed law automatically revise mps salaries every years
# 실제 정답 요약: president monthly salary go lakh lakh
# 예측(딥러닝)  :  polls women two two made russia two
# 예측(Summa)   : Earlier this year, eBay also invested $500 million into the Indian e-commerce startup.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 55] ===
# 정제된 원문  : reacting armed guard taking <UNK> downing street houses uk pm residence user tweeted surely <UNK> always given much protection others wrote vision post brexit future want <UNK> need fight guns <UNK> feels walk past sibling snacks
# 실제 정답 요약: twitter reacts armed guard taking <UNK> <UNK>
# 예측(딥러닝)  :  us becomes us singh president accused harassment
# 예측(Summa)   : Mukesh Ambani is close to acquiring a majority stake in Mumbai-based edtech startup Embibe via his family office for Ã¢ÂÂ¹100 crore, according to reports.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 56] ===
# 정제된 원문  : extending support andhra pradesh leaders demanding special category status state congress president rahul gandhi tuesday said party fulfil demand voted power general elections ruling tdp part bjp led nda alliance also protesting centre alleging neglected andhra pradesh
# 실제 정답 요약: give special status andhra voted power rahul
# 예측(딥러닝)  :  polls women men accused two post post
# 예측(Summa)   : Serbia is preparing a lawsuit against NATO over its alleged use of depleted Uranium munitions during its three-month bombing of Yugoslavia 18 years ago during the Kosovo War.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 57] ===
# 정제된 원문  : indian tennis player sania mirza posted picture medals asian games mirza participating edition wrote first time since competing asian games representing country little sad feeling nostalgic sania wrote
# 실제 정답 요약: sania mirza shares photo asian games medals
# 예측(딥러닝)  :  made security suicide two post suicide suicide
# 예측(Summa)   : Cannabis possession first became a crime in Canada in 1923 but medical use has been legal since 2001.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 58] ===
# 정제된 원문  : saudi arabia united arab emirates pledged combined million women entrepreneurs fund proposed us president donald trump daughter ivanka trump according reports fund ivanka first proposed germany trip run world bank help female entrepreneurs capital networking resources start businesses
# 실제 정답 요약: saudi uae pledge million ivanka trump proposed
# 예측(딥러닝)  :  army test flight flight flight china win
# 예측(Summa)   : Actor Rajkummar Rao revealed that his loved ones wanted him to add an extra 'M' in his name, while adding, "But, it's not like just because of that suddenly things changed for me.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 59] ===
# 정제된 원문  : voting member madhya pradesh assembly member mizoram assembly began today madhya pradesh bjp power since around polling booths set would entirely operated women whereas mizoram congress power since lal thanhawla chief minister
# 실제 정답 요약: voting madhya pradesh mizoram assembly elections begins
# 예측(딥러닝)  :  us women chinese ram ram home home
# 예측(Summa)   : Four people were killed by a speeding train while trying to cross a railway track in Hathras district on Thursday, Uttar Pradesh police said.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 60] ===
# 정제된 원문  : railway bridges india years old minister state railways rajen gohain informed lok sabha wednesday asserting age bridge directly related physical condition minister said bridges inspected twice year indian railways total lakh bridges
# 실제 정답 요약: railway <UNK> india years old
# 예측(딥러닝)  :  polls women two post post post two
# 예측(Summa)   : Defending his decision to impose retaliatory tariffs on foreign goods, US President Donald Trump cited India as an example of those countries imposing 100% tariffs on American products.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 61] ===
# 정제된 원문  : iit guwahati scientists synthesised mats made silk proteins <UNK> glass fibres could assist growth bone cells repair worn joints arthritis patients mats bond native tissue eventually degrade new tissue formed place lab tests artificial tissue formed efficiently within two weeks researchers said
# 실제 정답 요약: iit scientists develop silk <UNK> could treat
# 예측(딥러닝)  :  billion women post post back back back
# 예측(Summa)   : Talking about Ranbir Kapoor who portrays him in 'Sanju', Sanjay Dutt has said he bets the former has had over 10 affairs.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 62] ===
# 정제된 원문  : twenty three time grand slam champion serena williams took social media open struggles <UNK> depression saying felt like good mom last week serena suffered career worst defeat last week wrote although every day life around much would like
# 실제 정답 요약: felt good mom serena <UNK> <UNK>
# 예측(딥러닝)  :  us becomes us singh two firm firm
# 예측(Summa)   : The patents were granted to various IBM researchers, engineers, scientists and designers across the US and 47 other countries.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 63] ===
# 정제된 원문  : woman hyderabad stranded kuwait rescued indian embassy officials mother wrote letter external affairs minister sushma swaraj woman claimed agent lured promise job <UNK> however said forced work housemaid tortured employers
# 실제 정답 요약: woman rescued kuwait mom seeks swaraj help
# 예측(딥러닝)  :  us women us two chinese air air
# 예측(Summa)   : Silicon Valley-based startup Juicero, which makes smart juicers that sell for over Ã¢ÂÂ¹25,000, on Friday announced that it is shutting down.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 64] ===
# 정제된 원문  : per reports actress deepika padukone approached star opposite prabhas upcoming bollywood film makers also said considering alia bhatt katrina kaif deepika rejects film earlier prabhas said <UNK> script three years ago love story post saaho
# 실제 정답 요약: deepika approached star opposite prabhas film report
# 예측(딥러닝)  :  army law flight flight reports singh study
# 예측(Summa)   : Speaking about his daughter, Ramalinga said, "She had a desire to help people." n
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 65] ===
# 정제된 원문  : year old man florida us arrested allegedly attacking neighbour <UNK> word kindness written victim another neighbour walked bryan stewart house tell keep noise accused stewart carried attack heard threatening kill someone kindness
# 실제 정답 요약: us man attacks neighbour <UNK> named <UNK>
# 예측(딥러닝)  :  us women offers president train study shares
# 예측(Summa)   : Chennai Super Kings on Tuesday defeated SunRisers Hyderabad in the Qualifier 1 to reach Indian Premier League final for the seventh time.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 66] ===
# 정제된 원문  : maharashtra based couple filed police complaint picture shared social media account holi circulated meme woman posted photograph husband left coloured <UNK> chest would never thought would <UNK> cheap manner woman said
# 실제 정답 요약: couple files complaint holi pic circulated meme
# 예측(딥러닝)  :  indian women using announces train train shares
# 예측(Summa)   : Students on Friday protested outside the White House against rising cases of gun violence in the US.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 67] ===
# 정제된 원문  : delay joint military drills us depend north korea behaviour south korean official said wednesday north korea termed recent us south korea drills provocation accusing us begging nuclear war staging military exercise us south korea staged drills north korea nuclear programme
# 실제 정답 요약: could delay drills <UNK> north behaviour korea
# 예측(딥러닝)  :  polls women men men two men father
# 예측(Summa)   : President Ram Nath Kovind has said that youth shouldn't get carried away by the instantness of technology.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 68] ===
# 정제된 원문  : india proposed introduce million retaliatory tariffs list items imported us india asked us exempt tariffs steel aluminium us rejected request india notified world trade organisation list including apples <UNK> motorcycles intends impose tariffs
# 실제 정답 요약: india proposes mn retaliatory tariffs us products
# 예측(딥러닝)  :  army test india flight flight china china
# 예측(Summa)   : Talking about her son Osama bin Laden, mastermind behind 9/11 attack, Alia Ghanem said, "He was a very good child until he met some people who pretty much brainwashed him in his early 20s.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 69] ===
# 정제된 원문  : india first indigenous sniper rifle launched wednesday rifle factory west bengal <UNK> worth lakh weighing kg rifle shooting range metres one advantages reportedly abundance ammunition factory received orders crpf police forces haryana rajasthan
# 실제 정답 요약: india gets first indigenous <UNK> rifle
# 예측(딥러닝)  :  polls women two two russia russia russia
# 예측(Summa)   : Police in Kalaburagi district of Karnataka gave roses to people following traffic norms and wearing helmets and booked those who were seen flouting the rules.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 70] ===
# 정제된 원문  : canadian woman slammed british airways claiming seven year old daughter left bleeding bitten bugs flight woman added given different seats even raising issue crew twice meanwhile british airways spokesman said airline apologised woman family
# 실제 정답 요약: british airways slammed bed bugs plane seats
# 예측(딥러닝)  :  billion women suicide suicide accused singh singh
# 예측(Summa)   : Condemning UK's terror attack which killed 22 people and injured 59 others, Iranian Foreign Ministry spokesman Bahram Qasemi said, "Artificial alliances would not stop the expansion of cancerous terrorism in the world.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 71] ===
# 정제된 원문  : recently revealed memo warning employees leak confidential details apple said apple caught <UNK> arrested giving example employee leaked information apple said thought would discovered <UNK> whether employees contractors get caught getting caught faster ever apple pointed
# 실제 정답 요약: caught <UNK> arrested apple
# /tmp/ipykernel_170/1442834169.py:25: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   input_seq = torch.tensor(encoder_input_test[i], dtype=torch.long, device=device).unsqueeze(0)
# /tmp/ipykernel_170/366614501.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   input_seq = torch.tensor(input_seq, dtype=torch.long, device=device)
# 예측(딥러닝)  :  us test chinese ram home home home
# 예측(Summa)   : Waghmore further said he didn't know who Lankesh was and added that he should not have killed her.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 72] ===
# 정제된 원문  : saudi arabia general security division sunday allowed women aged apply rank soldier part vision social program launched crown prince mohammad bin salman however saudi women fulfil conditions including mandatory medical check good weight height ratio
# 실제 정답 요약: saudi arabia allows women join armed forces
# 예측(딥러닝)  :  indian women using announces train train shares
# 예측(Summa)   : After UP Chief Minister Yogi Adityanath spoke to Ramdev and Patanjali Ayurved MD Acharya Balkrishna, the company said its proposed mega food park will not be shifted out of the state.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 73] ===
# 정제된 원문  : rjd leader bhai <UNK> monday refused remove red beacon atop car said order bihar government cabinet decided bihar follow decision delhi cabinet government pass order follow rule said
# 실제 정답 요약: rjd leader refuses remove red beacon car
# 예측(딥러닝)  :  polls women two two suicide suicide suicide
# 예측(Summa)   : Notably, Google Assistant has been pegged as direct competition for Apple's own digital assistant 'Siri'.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 74] ===
# 정제된 원문  : government preparing digital atlas flood prone areas give warnings real time information rise water levels reports said help local administrations reduce damage property loss life floods reports added flood warning system india currently based water level forecasting
# 실제 정답 요약: govt plans digital <UNK> flood prone areas
# 예측(딥러닝)  :  polls women post post post post post
# 예측(Summa)   : The Supreme Court has asked the chief secretaries of Delhi and Haryana to hold a meeting with the Water Resources Ministry and settle the ongoing dispute over sharing river Yamuna's water.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 75] ===
# 정제된 원문  : many whales died washed ashore western australia rescue operations underway save remaining authorities warned public avoid area dying animals could attract sharks closer shore largest mass <UNK> whales region happened long <UNK> pilot whales washed ashore
# 실제 정답 요약: whales die mass <UNK> australian beach
# 예측(딥러닝)  :  flight offers flight train yr home study
# 예측(Summa)   : Indian batsmen Murali Vijay and Cheteshwar Pujara slammed their 10th and 14th Test tons respectively as India ended the second day of the second Test at 312/2, leading Sri Lanka by 107 runs.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 76] ===
# 정제된 원문  : australian court granted queensland woman right use dead boyfriend sperm children woman relationship man three years killed notably illegal queensland take store transport use ivf man sperm without written consent
# 실제 정답 요약: aus woman allowed baby using dead partner
# 예측(딥러닝)  :  billion women two two post post back
# 예측(Summa)   : Responding to the concerns about the collection of data on non-users, Facebook has said, "This kind of data collection is fundamental to how the internet works.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 77] ===
# 정제된 원문  : talking social media platforms like facebook twitter us congressman steve king suggested converting large <UNK> organisations public utilities said hearing filtering practices social media platforms king suggestion followed inquiries facebook algorithm right wing website losing reach social media
# 실제 정답 요약: turn facebook twitter public <UNK> us <UNK>
# 예측(딥러닝)  :  us becomes chinese air air air air
# 예측(Summa)   : China's Ambassador Luo Zhaohui has said India and China should start a new chapter and make "one plus one eleven".
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 78] ===
# 정제된 원문  : toshiba us nuclear unit <UNK> filed bankruptcy shareholder company meeting said toshiba become laughing stock around world clue going meeting saw shareholders vent ceo satoshi <UNK> toshiba shareholders agreed split nand flash memory unit raise money cover <UNK> charges
# 실제 정답 요약: <UNK> become laughing stock shareholder tells ceo
# 예측(딥러닝)  :  us women mn announces train air leader
# 예측(Summa)   : While referring to his cutting off analysts' questions during a conference call, Tesla CEO Elon Musk has said, "It was foolish of me to ignore them.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 79] ===
# 정제된 원문  : shia <UNK> starrer man released march earned opening weekend uk film shown one cinema hall given video demand release senior media analyst paul <UNK> wrote poor shia opening could guinness world records something
# 실제 정답 요약: shia le <UNK> film earns first weekend
# 예측(딥러닝)  :  polls women take train train russia singh
# 예측(Summa)   : Chief Election Commissioner OP Rawat has dismissed Congress' allegations on the commission's delay in announcement of election dates, saying, "Politicians and political parties have to see politics in everything because of their inherent nature.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 80] ===
# 정제된 원문  : following incidents violence filing nominations west bengal panchayat polls state congress chief <UNK> chowdhury demanded president rule state without imposing president rule one able exercise democratic right chowdhury said bjp also complained party workers attacked trying file nominations
# 실제 정답 요약: need president rule wb cong panchayat poll
# 예측(딥러닝)  :  us women us two two firm firm
# 예측(Summa)   : The CBSE has allowed 15-year-old shooter Anish Bhanwala to take three 10th Board examination papers at a later time in April as he will participate in Commonwealth Games and ISSF Junior World Cup.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 81] ===
# 정제된 원문  : scuffle broke bjp bsp workers uttar pradesh one newly elected corporators latter took oath urdu aligarh municipal corporation adding people objected raised slogans ceremony aligarh district magistrate said authorities probe recordings ceremony take action accordingly
# 실제 정답 요약: bjp bsp workers clash corporator takes oath
# 예측(딥러닝)  :  court offers flight train <UNK> yr home
# 예측(Summa)   : The prison-mates reportedly ransacked several barracks in the jail and caused loss to government properties.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 82] ===
# 정제된 원문  : much road <UNK> put delhi ncr non standard wrongfully installed according survey conducted institute road traffic education many accidents recent times could averted road <UNK> mark <UNK> president dr rohit <UNK> said
# 실제 정답 요약: road <UNK> delhi ncr incorrect traffic survey
# 예측(딥러닝)  :  us offers flight train russia yr home
# 예측(Summa)   : Aayush Sharma, while talking about the ongoing controversy surrounding the title of his upcoming film 'Loveyatri', has said, "I don't want to win the box office with a controversy." "I don't think getting controversy or adding tension would have worked in my favour.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 83] ===
# 정제된 원문  : grenade found well delhi red fort thursday evening prompting team national security guard swing action nsg safely removed grenade red fort preliminary inquiry suggests old grenade said jatin <UNK> dcp
# 실제 정답 요약: grenade found well delhi red fort
# 예측(딥러닝)  :  us women offers president train russia dead
# 예측(Summa)   : The student said he re-wrote the lyrics to the song.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 84] ===
# 정제된 원문  : marks spencer <UNK> suspended buying chicken uk sisters food group owned west <UNK> factory comes investigation guardian revealed supplier tampering food safety records <UNK> said commenced investigation claims workers factory changing slaughter dates poultry potentially making unsafe
# 실제 정답 요약: stops business chicken supplier hygiene issues
# 예측(딥러닝)  :  billion women two two post post back
# 예측(Summa)   : Nitasha, winner of transgender beauty pageant Miss Trans Queen, said before her transition her father wanted a girl for her, as she was biologically male at that time, but she was sure she wanted to marry a boy.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 85] ===
# 정제된 원문  : stephen <UNK> vice president marvel jokingly said marvel makes indian content shah rukh khan said stories set different countries goal always use actors part world added try create characters real <UNK> indian culture
# 실제 정답 요약: srk indian content marvel makes jokes executive
# 예측(딥러닝)  :  us becomes us men firm firm two
# 예측(Summa)   : Earlier, reports claimed BJP chief Amit Shah and Raje were having differences in finalising the names of candidates.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 86] ===
# 정제된 원문  : school us city boston using nursery rhyme teach kindergarten students survive school shootings according reports lockdown poem supposed sung tune poem twinkle twinkle little star comes part measures tackle school shootings us
# 실제 정답 요약: <UNK> <UNK> teaches us kids survive school
# 예측(딥러닝)  :  us women using announces train train russia
# 예측(Summa)   : A new Android malware that targets over 232 banking apps, including those of SBI, HDFC, and IDBI, has been discovered.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 87] ===
# 정제된 원문  : colombia <UNK> rebels reportedly launch political party conference beginning sunday choose party name candidates next year general elections comes year old conflict colombian government <UNK> ended earlier month following final disarmament weapons rebels un
# 실제 정답 요약: colombia <UNK> rebels launch political party
# 예측(딥러닝)  :  us women flight win accused accused father
# 예측(Summa)   : Criticising technology billionaire leaders for not giving enough charity, cloud computing company Salesforce CEO Marc Benioff has said, "A lot of them are just hoarding it.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 88] ===
# 정제된 원문  : teaser rishi kapoor taapsee pannu starrer mulk released taapsee seen playing role lawyer named aarti mohammed rishi portray man named murad ali mohammed accused directed co produced anubhav sinha mulk scheduled release august
# 실제 정답 요약: teaser rishi kapoor taapsee pannu starrer mulk
# 예측(딥러닝)  :  us women president offers president train shares
# 예측(Summa)   : The Assam Police has clarified that the notice asking retired Indian Army officer Mohammad Azmal Haque to prove his citizenship was sent to him due to 'mistaken identity'.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 89] ===
# 정제된 원문  : <UNK> actress <UNK> ali sardar recently got trolled picture said someone expects look years ago something wrong someone people use photo technologies filters look different beautiful photos everyone else cannot said
# 실제 정답 요약: wrong expect look yrs ago <UNK> actress
# 예측(딥러닝)  :  us women us two chinese air air
# 예측(Summa)   : It starts with an ageing red giant star losing mass via stellar wind, which balloons into a huge gaseous shell around the star.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 90] ===
# 정제된 원문  : diary late united states president john kennedy kept days journalist world war ii sold auction wednesday page diary kennedy suspected hitler dead stuff legends made expressing doubts united nations effectiveness
# 실제 정답 요약: john <UNK> <UNK> journalist sells crore
# 예측(딥러닝)  :  us women offers president train russia shares
# 예측(Summa)   : For the first time in their history, Real Madrid lost a match against Tottenham Hotspur, going down 1-3 in the Champions League group stage on Wednesday.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 91] ===
# 정제된 원문  : maldives high commissioner ahmed mohamed said country wanted send special envoy india cancelled proposed visit informed dates suitable indian government comes reported maldives amid political crisis sent envoys friendly countries india
# 실제 정답 요약: wanted send envoy dates suit india maldives
# 예측(딥러닝)  :  polls security air ram air leader two
# 예측(Summa)   : Pilots of the Dubai-bound Air India Express flight carrying 130 passengers were unaware of the plane hitting the wall at the Trichy airport during takeoff on Friday at 1:30 am.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 92] ===
# 정제된 원문  : saif ali khan asked reporter wife kareena kapoor comeback responded saying asked question would probably thrown shoe according always around added kareena next seen film veere di wedding
# 실제 정답 요약: kareena throw shoe asked comeback saif
# 예측(딥러닝)  :  us women mn mn mn two two
# 예측(Summa)   : An 11-year-old girl is set to become Britain's youngest mother with police investigating the circumstances of her pregnancy.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 93] ===
# 정제된 원문  : filmmaker vikas bahl moved bombay high court crore defamation suit former phantom films partners anurag kashyap vikramaditya motwane bahl also sought direction hc restrain making statement media via social media bahl accused sexual harassment former employee phantom films
# 실제 정답 요약: vikas bahl files cr defamation suit anurag
# 예측(딥러닝)  :  court singh us co ram ram ram
# 예측(Summa)   : The couple, which plans to leave the establishment, said they are "ready for a new adventure".
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 94] ===
# 정제된 원문  : chhattisgarh cm raman singh said india dharamshala people outside keep entering country speaking nrc issue singh said must deported people marked result eight year long protest assamese youth either lakh people prove identity go back
# 실제 정답 요약: india <UNK> chhattisgarh cm raman singh nrc
# 예측(딥러닝)  :  made women post post post post two
# 예측(Summa)   : Former Indian captain Sourav Ganguly said, "Usman Khawaja has been found out by the Indian attack to the extent that even if he is asleep, Ravichandran Ashwin and Ravindra Jadeja can dismiss him in his dreams.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 95] ===
# 정제된 원문  : wake heightened tension two nations regarding kulbhushan jadhav case pakistan said india capable producing nuclear weapons india world fastest growing nuclear programme added pakistan statement regarding india enhancing nuclear capability come days reports suggested new delhi may <UNK> nuclear doctrine
# 실제 정답 요약: india <UNK> make nuclear weapons pakistan
# 예측(딥러닝)  :  polls security men two post post post
# 예측(Summa)   : Google's self-driving car spinoff company Waymo has started testing autonomous truck technology.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 96] ===
# 정제된 원문  : first meeting un general assembly comprising nations convened westminster central hall london england january meeting saw election belgium paul henri <UNK> first president general assembly established <UNK> <UNK> representative organ un
# 실제 정답 요약: first meeting united nations held years ago
# 예측(딥러닝)  :  us women flight win accused singh shares
# 예측(Summa)   : The all-electric robot can also handle objects and climbs stairs.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 97] ===
# 정제된 원문  : microsoft president brad smith accused north korea carrying wannacry cyber attack hit two lakh computers across countries earlier year adding north korea used cyber tools stolen us national security agency smith said last six months world seen threats come life serious way
# 실제 정답 요약: korea carried wannacry cyber attack microsoft prez
# 예측(딥러닝)  :  polls women post two post post two
# 예측(Summa)   : He also said it was up to Sonia Gandhi if she wanted to continue as party chief for another term.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 98] ===
# 정제된 원문  : two men staged mock wedding <UNK> tamil nadu protest reopening state owned liquor shops state people earlier forced closure liquor outlets citing ill effects alcohol shops reopened recently protestors staging mock wedding saying alcoholic let women marry
# 실제 정답 요약: men marry protest <UNK> liquor shops tn
# 예측(딥러닝)  :  us women offers president train russia shares
# 예측(Summa)   : A man tried to self-immolate outside a theatre in Varanasi screening the film 'Padmaavat'.
#
# ----------------------------------------------------------------------
#
# === [Sample Index: 99] ===
# 정제된 원문  : university chinese city <UNK> offering weight loss course students whose body mass index higher year long course encourages students lose weight exercise diet control grade determined much weight lose university introduced course realising students gaining weight
# 실제 정답 요약: university offers weight loss course <UNK> students
# 예측(딥러닝)  :  flight test flight flight accused singh study
# 예측(Summa)   : Of the Ã¢ÂÂ¹42,226 crore lost due to cheating and forgery, 89% was lost by state-owned banks.
#
# ----------------------------------------------------------------------

# %% [markdown]
# 추상/추출요약 결과 비교(50~99 예문)
#
# 1-1) 추상요약 결과 - 문법적으로 이상하고, 같은 단어가 계속 반복되어 나오면서 해석이 불가능한 요약들이 많음. 원문에도 없는 단어도 나옴
#
# 1-2) 저품질 원인- 제미나이는 모델의 학습 데이터가 절대적으로 부족하여 과소적합되었거나, 문장을 생성할 때 사용하는 디코딩 알고리즘에서 이전에 나온 단어를 제어하는 패널티 로직이 부족할 때 이런 현상이 발생
#
#
# 2-1)추출요약(Summa) - 문법적 논리가 있어서 상대적으로 해석이 가능한 예시들이 많이 보이나 여전히 원문과 전혀 맞지 않는 내용들이 많음
#
# 2-2) 저품질 원인 - encoder_input_test[i]가 가리키는 뉴스 가위바위보 순서와 test_df['text'].iloc[i]로 가져온 원문 데이터프레임의 행 순서가 완전히 어긋나 있음. 데이터가 train_test_split 과정에서 셔플(Shuffle)되었기 때문에, iloc[i]로 가져오면 엉뚱한 행의 원래 뉴스를 가져와 요약하면서 엉뚱한 내용이 나온것이라고 언급
#
# 2-3) 해결방안 - summa 인덱스 매칭, epoch를 더 늘리고 lr  조정 필요
